# %%
import requests
url = "https://www.vscinemas.com.tw/vsweb/film/index.aspx"
response = requests.get(url)
if response.status_code == 200:
    print("下載成功")
    print(response.text)
# Out:
# 下載成功
#
# <!DOCTYPE html>
# <html>
#   <head><!--[if lt IE 9]>
#     <script src="../js/html5.js"></script><![endif]-->
#     <!-- mata資訊-->
#         <!-- meta [start]-->
#         <title>威秀影城 - 熱售中</title>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width,initial-scale=1, maximum-scale=1, user-scalable=yes">
#         <meta name="description" content="威秀影城（VIESHOW CINEMAS），自1998年營業至今，為台灣最大的連鎖影城，全台共計13座據點。威秀影城擁有最出色的播映設備，包括數位IMAX和3D設備，也是全台首座結合商場而成的複合式影城，也因影城多角化經營而讓威秀影城成為台灣影城界的領導品牌。">
#         <meta name="keywords" content="威秀,電影訂票,電影,影城,戲院">
#         <meta name="author" content="威秀影城 - VIESHOW CINEMAS">
#         <meta name="copyright" content="威秀影城 - VIESHOW CINEMAS">
#         <meta name="Robots" content="all">
#         <meta http-equiv="content-language" content="zh-TW">
#         <meta name="revisit-after" content="7 days">
#         <meta name="distribution" content="GLOBAL">
#         <meta name="GOOGLEBOT" content="index, follow">
#         <meta property="og:title" content="威秀影城 - VIESHOW CINEMAS">
#         <meta property="og:description" content="威秀影城（VIESHOW CINEMAS），自1998年營業至今，為台灣最大的連鎖影城，全台共計13座據點。威秀影城擁有最出色的播映設備，包括數位IMAX和3D設備，也是全台首座結合商場而成的複合式影城，也因影城多角化經營而讓威秀影城成為台灣影城界的領導品牌。">
#         <meta property="og:site_name" content="威秀影城 - VIESHOW CINEMAS">
#         <meta property="og:type" content="company">
#         <meta property="og:image" content="/images/thumbnail.jpg">
#         <link rel="image_src" href="../images/thumbnail.jpg">
#         <link rel="shortcut icon" href="/favicon.ico">
#         <!-- meta [end]-->
#     <!-- Source [jquery] (lib)-->
#     <script type="text/javascript" src="../js/jquery-2.1.0.min.js"></script>
#     <!-- form check-->
#     <link rel="stylesheet" href="../js/validation/validationEngine.jquery.css">
#     <script type="text/javascript" charset="utf-8" src="../js/validation/jquery-migrate-1.1.0.js"></script>
#     <script type="text/javascript" charset="utf-8" src="../js/validation/languages/jquery.validationEngine-zh_TW.js"></script>
#     <script type="text/javascript" charset="utf-8" src="../js/validation/jquery.validationEngine.js"></script>
#     <!--scrolltop [toTop]-->
#     <script type="text/javascript" src="../js/scrolltopcontrol.js"></script>
#     <!-- Photo Swipe [photo display ]-->
#     <link rel="stylesheet" href="../js/photoSwipe/photoswipe.css">
#     <link rel="stylesheet" href="../js/photoSwipe/default-skin/default-skin.css">
#     <script type="text/javascript" src="../js/photoSwipe/photoswipe.min.js"></script>
#     <script type="text/javascript" src="../js/photoSwipe/photoswipe-ui-default.min.js"></script>
#     <style type="text/css">
#
#       .type05 { background-color: #AA7700; } .type05 mark{ color: #ffffff;}
#
#       .type02 { background-color: #7700BB; } .type02 mark{ color: #ffffff;}
#
#       .type03 { background-color: #F50000; } .type03 mark{ color: #ffffff;}
#
#       .type12 { background-color: #C30D23; } .type12 mark{ color: #ffffff;}
#
#       .type32 { background-color: #F50000; } .type32 mark{ color: #ffffff;}
#
#       .type40 { background-color: #000000; } .type40 mark{ color: #ffffff;}
#
#       .type43 { background-color: #FF6A6A; } .type43 mark{ color: #ffffff;}
#
#       .type01 { background-color: #EE7700; } .type01 mark{ color: #ffffff;}
#
#       .type04 { background-color: #EE7700; } .type04 mark{ color: #ffffff;}
#
#       .type34 { background-color: #F75000; } .type34 mark{ color: #ffffff;}
#
#       .type38 { background-color: #EEB100; } .type38 mark{ color: #ffffff;}
#
#       .type45 { background-color: #EEB100; } .type45 mark{ color: #ffffff;}
#
#       .type52 { background-color: #7700BB; } .type52 mark{ color: #ffffff;}
#
#       .type54 { background-color: #7700BB; } .type54 mark{ color: #ffffff;}
#
#       .type55 { background-color: #AE8F00; } .type55 mark{ color: #ffffff;}
#
#       .type42 { background-color: #AE8F00; } .type42 mark{ color: #ffffff;}
#
#       .type22 { background-color: #AE8F00; } .type22 mark{ color: #ffffff;}
#
#       .type30 { background-color: #888800; } .type30 mark{ color: #ffffff;}
#
#       .type31 { background-color: #AE8F00; } .type31 mark{ color: #ffffff;}
#
#       .type26 { background-color: #FF8000; } .type26 mark{ color: #ffffff;}
#
#       .type36 { background-color: #2828FF; } .type36 mark{ color: #ffffff;}
#
#       .type33 { background-color: #FF8000; } .type33 mark{ color: #ffffff;}
#
#       .type20 { background-color: #8C0044; } .type20 mark{ color: #ffffff;}
#
#       .type21 { background-color: #8C0044; } .type21 mark{ color: #ffffff;}
#
#       .type08 { background-color: #7D7D7D; } .type08 mark{ color: #ffffff;}
#
#       .type09 { background-color: #292421; } .type09 mark{ color: #ffffff;}
#
#       .type44 { background-color: #292421; } .type44 mark{ color: #ffffff;}
#
#       .type10 { background-color: #EEB100; } .type10 mark{ color: #ffffff;}
#
#     </style>
#     <!-- Code-->
#     <script type="text/javascript" src="../js/share.js"></script>
#     <script type="text/javascript" src="../js/inside.js"></script>
#     <!-- Style-->
#     <link rel="stylesheet" href="../css/styles.css">
#     <link rel="stylesheet" href="../css/reset.css">
#     <link rel="stylesheet" href="../css/share.css">
#     <link rel="stylesheet" href="../css/inside.css">
#   </head>
#   <body>
#     <div id="top"></div>
#
#
#     <!--公告圖片的燈箱--><!-- Popup區塊 [start] -->
#     <div class="liveAD">
#     <!-- 燈箱開啟區塊 [start] -->
#     <!-- Root element of PhotoSwipe. Must have class pswp. -->
#     <div id="gallery" class="pswp" tabindex="-1" role="dialog" aria-hidden="true">
#         <div class="pswp__bg"></div>
#
#         <div class="pswp__scroll-wrap">
#
#             <div class="pswp__container">
#                 <div class="pswp__item">
#                     <div class="pswp__zoom-wrap">
#                     </div>
#                 </div>
#                 <div class="pswp__item">
#                     <div class="pswp__zoom-wrap"></div>
#                 </div>
#                 <div class="pswp__item">
#                     <div class="pswp__zoom-wrap"></div>
#                 </div>
#             </div>
#
#             <div class="pswp__ui pswp__ui--fit pswp__ui--hidden">
#
#                 <div class="pswp__top-bar">
#
#                     <div class="pswp__counter"></div>
#
#                     <button class="pswp__button pswp__button--close" title="Close (Esc)"></button>
#
#                     <button class="pswp__button pswp__button--share" title="Share"></button>
#
#                     <button class="pswp__button pswp__button--fs" title="Toggle fullscreen"></button>
#
#                     <button class="pswp__button pswp__button--zoom" title="Zoom in/out"></button>
#
#                     <div class="pswp__preloader">
#                         <div class="pswp__preloader__icn">
#                             <div class="pswp__preloader__cut">
#                                 <div class="pswp__preloader__donut"></div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#
#                 <div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
#                     <div class="pswp__share-tooltip"></div>
#                 </div>
#
#                 <button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)"></button>
#                 <button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)"></button>
#                 <div class="pswp__caption">
#                     <div class="pswp__caption__center"></div>
#                 </div>
#             </div>
#
#         </div>
#     </div>
#     <!-- 燈箱開啟區塊 [End] -->
# </div>
# <!-- Popup區塊 [end] -->
#     <!--售票公告圖檔，#popup1為點擊時要開啟的圖，預設為第一張。-->
#     <div itemscope="" data-pswp-uid="1" class="publicNote">
#
#         <figure itemscope><a id="popup1" href="../upload/help/help_20200929001.jpg" itemprop="contentUrl" data-size="600x600"><img u="image" src="../upload/help/help_20200929001.jpg" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">售票時間</figcaption>
#         </figure>
#
#     </div>
#     <!--入場須知圖檔，#popup2為點擊時要開啟的圖，預設為第一張。-->
#     <div itemscope="" data-pswp-uid="1" class="publicInfo">
#
#         <figure itemscope><a id="popup2" href="../upload/help/help_20161230001.jpg" itemprop="contentUrl" data-size="1280x956"><img u="image" src="../upload/help/help_20161230001.jpg" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">電影分級</figcaption>
#         </figure>
#
#         <figure itemscope><a id="popup2" href="../upload/help/help_20191003001.jpg" itemprop="contentUrl" data-size="650x1083"><img u="image" src="../upload/help/help_20191003001.jpg" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">入場須知</figcaption>
#         </figure>
#
#     </div>
#
#
#
#     <!--3-->
#     <div itemscope="" data-pswp-uid="1" class="publicInfo">
#
#         <figure itemscope><a id="popup3" href="../upload/images/01.jpg" itemprop="contentUrl" data-size="1024x768"><img u="image" src="../upload/images/b01.png" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">獨享票價優惠及餐飲折扣</figcaption>
#         </figure>
#
#     </div>
#
# 		<!--4-->
#     <div itemscope="" data-pswp-uid="1" class="publicInfo">
#
#         <figure itemscope><a id="popup4" href="../upload/images/02.jpg" itemprop="contentUrl" data-size="1024x768"><img u="image" src="../upload/images/b02.png" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">平日累點1.5倍 兌點改版更Easy</figcaption>
#         </figure>
#
#     </div>
#
# 		<!--5-->
#     <div itemscope="" data-pswp-uid="1" class="publicInfo">
#
#         <figure itemscope><a id="popup5" href="../upload/images/03.jpg" itemprop="contentUrl" data-size="1024x768"><img u="image" src="../upload/images/b03.png" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">儲值再送iShow點數及電影票</figcaption>
#         </figure>
#
#     </div>
#
# 		<!--6-->
#     <div itemscope="" data-pswp-uid="1" class="publicInfo">
#
#         <figure itemscope><a id="popup6" href="../upload/images/04.jpg" itemprop="contentUrl" data-size="1024x768"><img u="image" src="../upload/images/b04.png" itemprop="thumbnail" /></a>
#             <figcaption itemprop="caption description">電影票/餐飲兌換最速攻略</figcaption>
#         </figure>
#
#     </div>
#
#
# <header class="header">
#     <div class="topArea">
#         <a href="https://www.vscinemas.com.tw/vsweb/index.aspx" class="logo">
#             <img src="https://www.vscinemas.com.tw/vsweb/images/vscinemas_logo.png" alt="威秀影城 - VIESHOW CINEMAS" title="威秀影城 - VIESHOW CINEMAS"></a><a class="icon-menu"></a>
#         <section class="menuAll">
#             <!--上方連結-->
#             <ul class="topLink">
#
#                 <li class="firstLink"><a href="#" class="first">連絡威秀</a>
#                     <ul>
#                         <li><a href="#" class="openTel">服務專線</a></li>
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/contact/contact.aspx">企業合作</a></li>
#
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/about/responselogin.aspx" target="_blank">顧客意見</a></li>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/contact/theater_booking.aspx">包廳租借</a></li>
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/about/recruit.aspx">人才招募</a></li>
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/contact/advertisingagency.aspx">廣告託播</a></li>
#                     </ul>
#                 </li>
#                 <li class="firstLink"><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx" class="first">常見問題</a>
#                     <ul>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=1">會員問題</a></li>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=2">訂購票問題</a></li>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=3">優待券使用問題</a></li>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=5">電子發票</a></li>
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=4">其他問題</a></li>
#
#
#                         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/LostAndFound.aspx">遺失物服務</a></li>
#                     </ul>
#                 </li>
#
#
#                 <li><a href="https://sales.vscinemas.com.tw/VieShowTicket/Member/Deposit">會員登入</a></li>
#                 <li><a href="https://www.vscinemas.com.tw/Service/" target="_blank">會員服務</a></li>
#             </ul>
#             <ul class="iconLink">
#                 <li><a href="https://www.vscinemas.com.tw/vsweb/mk/line/index.html" target="_blank" class="icon-line"></a></li>
#                 <li><a href="https://www.facebook.com/vieshow" target="_blank" class="icon-social-facebook"></a></li>
#                 <li><a href="https://www.youtube.com/user/vieshowmodmore" target="_blank" class="icon-social-youtube"></a></li>
#                 <li><a href="https://www.instagram.com/vieshowbaby/" target="_blank" class="icon-instagram"></a></li>
#             </ul>
#             <!--主選單-->
#             <nav class="menu">
#                 <ul class="subMenu">
#
#                     <li class="mainLink"><a href="#" class="firstMenu">影城介紹</a>
#                         <ul class="sublink">
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/theater/index.aspx">威秀影城</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23">MUVIE</a></li>
#                         </ul>
#                     </li>
#                     <li class="mainLink haveBanner"><a href="#" class="firstMenu">電影介紹</a>
#
#                         <div class="bannerGroup">
#                             <ul>
#                                 <!--<li><a href="https://www.vscinemas.com.tw/vsweb/film/hot.aspx">哈燒影榜</a></li>-->
#                                 <li><a href="https://www.vscinemas.com.tw/vsweb/film/index.aspx">熱售中</a></li>
#
#                                 <li><a href="https://www.vscinemas.com.tw/vsweb/film/coming.aspx">即將上映</a></li>
#                             </ul>
#
#                             <section class="sbannerArea">
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/film/index.aspx" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220608003.JPG" alt="【英國國家劇院現場 𝐍𝐓𝐋𝐢𝐯𝐞 第𝟏𝟑季】．熱賣中" title="【英國國家劇院現場 𝐍𝐓𝐋𝐢𝐯𝐞 第𝟏𝟑季】．熱賣中"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/film/index.aspx" target="_self">【英國國家劇院現場 𝐍𝐓𝐋𝐢𝐯𝐞 第𝟏𝟑季】．熱賣中<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/event/detail.aspx?id=1830" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220617001.jpg" alt="iShow會員最新【兌點禮】" title="iShow會員最新【兌點禮】"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/event/detail.aspx?id=1830" target="_self">iShow會員最新【兌點禮】<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/event/detail.aspx?id=2024" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220617002.jpg" alt="《中和環球威秀影城限定》【巴斯光年】特別場" title="《中和環球威秀影城限定》【巴斯光年】特別場"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/event/detail.aspx?id=2024" target="_self">《中和環球威秀影城限定》【巴斯光年】特別場<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://bit.ly/3Qrs3H7" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220617003.jpg" alt="【雷神索爾：愛與雷霆】全台預售情報" title="【雷神索爾：愛與雷霆】全台預售情報"></a><h3><a href="https://bit.ly/3Qrs3H7" target="_self">【雷神索爾：愛與雷霆】全台預售情報<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                             </section>
#
#                         </div>
#                     </li>
#
#                     <li class="mainLink"><a href="#" class="firstMenu">映演品牌</a>
#                         <ul class="sublink">
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=12">TITAN SCREEN</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=13">MUCROWN</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=2">IMAX</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=1">4DX</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=3">GOLD CLASS</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=6">Mappa</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/concert/index.aspx">LIVE演唱會</a></li>
#                         </ul>
#                     </li>
#
#                     <li class="mainLink haveBanner"><a href="#" class="firstMenu">餐飲與商品</a>
#                         <div class="bannerGroup">
#                             <ul>
#                                 <li><a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx">影城餐飲</a></li>
#                                 <!--20161213暫拿<li><a href="https://www.vscinemas.com.tw/vsweb/themed/index.aspx">主題商品</a></li>-->
#                                 <li><a href="https://www.unicornpopcorn.com.tw/" target="_blank">UNICORN</a></li>
#
#
#                                 <li><a href="https://www.tori-kai.com/shop/rinkou.html" target="_blank">鳥開</a></li>
#                             </ul>
#
#                             <section class="sbannerArea">
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220610001.jpg" alt="獨家【侏羅紀世界：統霸天下】電影套餐" title="獨家【侏羅紀世界：統霸天下】電影套餐"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self">獨家【侏羅紀世界：統霸天下】電影套餐<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220610002.jpg" alt="【侏羅紀世界：統霸天下】電影套餐全台熱賣中" title="【侏羅紀世界：統霸天下】電影套餐全台熱賣中"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self">【侏羅紀世界：統霸天下】電影套餐全台熱賣中<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220610003.jpg" alt="立即購買【侏羅紀世界：統霸天下】電影套餐" title="立即購買【侏羅紀世界：統霸天下】電影套餐"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self">立即購買【侏羅紀世界：統霸天下】電影套餐<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                                 <figure>
#                                     <a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self"><img src="https://www.vscinemas.com.tw/vsweb/upload/homepage/homepage_20220610004.jpg" alt="威秀獨家【侏羅紀世界：統霸天下】電影套餐" title="威秀獨家【侏羅紀世界：統霸天下】電影套餐"></a><h3><a href="https://www.vscinemas.com.tw/vsweb/food/index.aspx" target="_self">威秀獨家【侏羅紀世界：統霸天下】電影套餐<br>
#                                            <span>MORE</span></a></h3>
#
#                                 </figure>
#
#                             </section>
#
#                         </div>
#                     </li>
#
#                     <li class="mainLink"><a href="#" class="firstMenu">活動公告</a>
#                         <ul class="sublink">
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/event/news.aspx">影城公告</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/event/index.aspx">影城活動</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/event/prize.aspx">中獎名單</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/event/partner.aspx">合作夥伴</a></li>
#                         </ul>
#                     </li>
#                     <li class="mainLink"><a href="https://www.vscinemas.com.tw/vsweb/biz/index.aspx">業務專區</a></li>
#
#                     <li class="mainLink"><a href="#" class="firstMenu">娛樂購物</a>
#                         <ul class="sublink">
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/mall/index.aspx">威秀商場</a></li>
#                             <li><a href="http://www.snowtown.com.tw/" target="_blank">雪樂地</a></li>
#                         </ul>
#                     </li>
#
#
#                     <li class="mainLink">
#                         <a href="#" class="firstMenu">會員專區</a>
#
#                         <ul class="sublink">
#                             <li class="onlyIshow"><a href="https://www.vscinemas.com.tw/vsweb/ishow/index.aspx">會員介紹</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/ishow/index.aspx">會員優惠</a></li>
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/ishow/card.aspx">申辦會員</a></li>
#                             <li><a href="https://sales.vscinemas.com.tw/vieshowticket/redeem" target="_blank">點數兌換</a></li>
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/event/index.aspx?E=1">會員活動</a></li>
#
#
#                             <li><a href="https://www.vscinemas.com.tw/vsweb/qa/qalist.aspx?A=1">會員Q&A</a></li>
#
#                         </ul>
#
#                     </li>
#                 </ul>
#             </nav>
#         </section>
#     </div>
#     <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-85040198-1', 'auto');
#         ga('send', 'pageview');
#     </script>
# </header>
# <!-- 服務專線-->
# <div class="serviceTel">
#     <h1 class="center">服務專線<a href="#" class="icon-delete"></a></h1>
#     <ul class="telList">
#
#         <li><span class="telTitle">台北信義威秀影城</span><span class="icon-phone"><a href="tel:0287805566">(02) 8780-5566</a></span></li>
#
#         <li><span class="telTitle">台北京站威秀影城</span><span class="icon-phone"><a href="tel:0225525511">(02) 2552-5511</a></span></li>
#
#         <li><span class="telTitle">板橋大遠百威秀影城</span><span class="icon-phone"><a href="tel:0277386608">(02) 7738-6608</a></span></li>
#
#         <li><span class="telTitle">中和環球威秀影城</span><span class="icon-phone"><a href="tel:0282266063">(02)8226-6063</a></span></li>
#
#         <li><span class="telTitle">林口MITSUI OUTLET PARK威秀影城</span><span class="icon-phone"><a href="tel:0226068099">(02) 2606-8099</a></span></li>
#
#         <li><span class="telTitle">桃園統領威秀影城</span><span class="icon-phone"><a href="tel:033333232">(03) 333-3232</a></span></li>
#
#         <li><span class="telTitle">新竹大遠百威秀影城</span><span class="icon-phone"><a href="tel:035241166">(03) 524-1166</a></span></li>
#
#         <li><span class="telTitle">新竹巨城威秀影城</span><span class="icon-phone"><a href="tel:035346999">(03) 534-6999</a></span></li>
#
#         <li><span class="telTitle">頭份尚順威秀影城</span><span class="icon-phone"><a href="tel:037686866">(037) 686-866</a></span></li>
#
#         <li><span class="telTitle">台中大遠百威秀影城</span><span class="icon-phone"><a href="tel:0422588511">(04) 2258-8511</a></span></li>
#
#         <li><span class="telTitle">台中TIGER CITY威秀影城</span><span class="icon-phone"><a href="tel:0436065566">(04) 3606-5566</a></span></li>
#
#         <li><span class="telTitle">台南大遠百威秀影城</span><span class="icon-phone"><a href="tel:066005566">(06) 600-5566</a></span></li>
#
#         <li><span class="telTitle">台南FOCUS 威秀影城</span><span class="icon-phone"><a href="tel:062223566">(06)-222-3566</a></span></li>
#
#         <li><span class="telTitle">台南南紡威秀影城</span><span class="icon-phone"><a href="tel:062372255">(06) 237-2255</a></span></li>
#
#         <li><span class="telTitle">高雄大遠百威秀影城</span><span class="icon-phone"><a href="tel:073345566">(07) 334-5566</a></span></li>
#
#         <li><span class="telTitle">花蓮新天堂樂園威秀影城</span><span class="icon-phone"><a href="tel:038421133">(03) 842-1133</a></span></li>
#
#     </ul>
# </div>
#
#
#
# <script type="text/javascript">
#     var strApiPath = "/VsWeb/api";
# </script>
# <script type="text/javascript" src="../js/helper.js"></script>
# <div class="searchBox">
#     <ul class="searchItem">
#         <li class="first"><a href="#" class="linkWord">快速訂票</a>
#             <section id="searchForm1" class="searchSet">
#                 <form class="bookBox">
#                     <ul>
#                         <li><span class="icon-marker"></span>
#                             <select name="cinema" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇影城</option>
#                             </select>
#                         </li>
#                         <li><span class="icon-video-1"></span>
#                             <select name="movie" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇影片</option>
#                             </select>
#                         </li>
#                         <li><span class="icon-calendar"></span>
#                             <select name="date" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇日期</option>
#                             </select>
#                         </li>
#                         <li><span class="icon-schedule"></span>
#                             <select name="session" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇場次</option>
#                             </select>
#                         </li>
#                     </ul>
#                     <section class="btnArea">
#                         <input type="button" value="前往訂票" onclick="javascript: booking();" />
#                         <a href="#" class="SessionSeats" id="SessionSeats" target="_blank">查看座位</a>
#                     </section>
#                 </form>
#             </section>
#         </li>
#         <li class="first"><a href="#" class="linkWord">快搜空位</a>
#             <section id="searchForm2" class="searchSet">
#                 <form action="https://www.vscinemas.com.tw/vsTicketing/ticketing/search_seat.aspx" method="get" class="findBox">
#                     <ul>
#                         <li><span class="icon-marker"></span>
#                             <select name="area" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇地區</option>
#                             </select>
#                         </li>
#                         <li><span class="icon-video-1"></span>
#                             <select name="film" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">請選擇影片</option>
#                             </select>
#                         </li>
#                         <li class="left"><span class="icon-calendar"></span>
#                             <select name="time" class="validate[required]">
#                                 <option value="">請選擇日期</option>
#                             </select>
#                         </li>
#                         <li class="left"><span class="icon-aurora-men"></span>
#                             <select name="number" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">幾人</option>
#                                 <option value="1">1</option>
#                                 <option value="2">2</option>
#                                 <option value="3">3</option>
#                                 <option value="4">4</option>
#                                 <option value="5">5</option>
#                                 <option value="6">6</option>
#                             </select>
#                         </li>
#                         <li class="left"><span class="icon-schedule"></span>
#                             <select name="from" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">時段(起)</option>
#
#                                 <option value="06:00">06:00 AM</option>
#
#                                 <option value="07:00">07:00 AM</option>
#
#                                 <option value="08:00">08:00 AM</option>
#
#                                 <option value="09:00">09:00 AM</option>
#
#                                 <option value="10:00">10:00 AM</option>
#
#                                 <option value="11:00">11:00 AM</option>
#
#                                 <option value="12:00">12:00 PM</option>
#
#                                 <option value="13:00">01:00 PM</option>
#
#                                 <option value="14:00">02:00 PM</option>
#
#                                 <option value="15:00">03:00 PM</option>
#
#                                 <option value="16:00">04:00 PM</option>
#
#                                 <option value="17:00">05:00 PM</option>
#
#                                 <option value="18:00">06:00 PM</option>
#
#                                 <option value="19:00">07:00 PM</option>
#
#                                 <option value="20:00">08:00 PM</option>
#
#                                 <option value="21:00">09:00 PM</option>
#
#                                 <option value="22:00">10:00 PM</option>
#
#                                 <option value="23:00">11:00 PM</option>
#
#                                 <option value="00:00">00:00 AM</option>
#
#                                 <option value="01:00">01:00 AM</option>
#
#                                 <option value="02:00">02:00 AM</option>
#
#                                 <option value="03:00">03:00 AM</option>
#
#                                 <option value="04:00">04:00 AM</option>
#
#                                 <option value="05:00">05:00 AM</option>
#
#                             </select>
#                         </li>
#                         <li class="left"><span class="icon-schedule"></span>
#                             <select name="to" data-prompt-position="topLeft" class="validate[required]">
#                                 <option value="">時段(迄)</option>
#
#                                 <option value="06:00">06:00 AM</option>
#
#                                 <option value="07:00">07:00 AM</option>
#
#                                 <option value="08:00">08:00 AM</option>
#
#                                 <option value="09:00">09:00 AM</option>
#
#                                 <option value="10:00">10:00 AM</option>
#
#                                 <option value="11:00">11:00 AM</option>
#
#                                 <option value="12:00">12:00 PM</option>
#
#                                 <option value="13:00">01:00 PM</option>
#
#                                 <option value="14:00">02:00 PM</option>
#
#                                 <option value="15:00">03:00 PM</option>
#
#                                 <option value="16:00">04:00 PM</option>
#
#                                 <option value="17:00">05:00 PM</option>
#
#                                 <option value="18:00">06:00 PM</option>
#
#                                 <option value="19:00">07:00 PM</option>
#
#                                 <option value="20:00">08:00 PM</option>
#
#                                 <option value="21:00">09:00 PM</option>
#
#                                 <option value="22:00">10:00 PM</option>
#
#                                 <option value="23:00">11:00 PM</option>
#
#                                 <option value="00:00">00:00 AM</option>
#
#                                 <option value="01:00">01:00 AM</option>
#
#                                 <option value="02:00">02:00 AM</option>
#
#                                 <option value="03:00">03:00 AM</option>
#
#                                 <option value="04:00">04:00 AM</option>
#
#                                 <option value="05:00">05:00 AM</option>
#
#                             </select>
#                         </li>
#                     </ul>
#                     <section class="btnArea">
#                         <input type="submit" value="前往訂票">
#                     </section>
#                 </form>
#             </section>
#         </li>
#     </ul>
# </div>
# <div class="qaBox">
#     <!--QA List-->
#
#     <ul class="insideQalist">
#         <li><span class="icon-commercia"></span><a href="https://www.vscinemas.com.tw/vsTicketing/ticketing/ticket.aspx" target="_blank" class="blank">線上訂票</a></li>
#         <li><span class="icon-speaker"></span><a href="#popup1" class="openNote">售票公告</a></li>
#         <li><span class="icon-exclamation"></span><a href="#popup2" class="openInfo">入場須知</a></li>
#
#         <li><span class="icon-schedule"></span><a href="https://www.vscinemas.com.tw/ShowTimes/" target="_blank" class="blank">場次查詢</a></li>
#
#     </ul>
# </div>
#
#
#     <!--麵包屑 crumb-->
#     <section class="crumbArea">
#       <div class="crumb"><span><a href="../index.aspx">首頁</a></span><span>熱售中</span></div>
#     </section>
#     <!--內容 Content-->
#     <article class="article">
#       <!--內容-->
#       <h1>熱售中</h1>
#
#       <ul class="movieList">
#
#         <li>
#           <figure><span class="type type05">
#             <mark>全版本</mark></span><span class="childview">
#             <mark></mark></span><a href="detail.aspx?id=5714"><img src="../upload/film/film_20220415001.jpg" alt="侏羅紀世界：統霸天下" title="侏羅紀世界：統霸天下"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span><span class="theaterMark">3D 數位</span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=2" target="_blank">IMAX</a></span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=3" target="_blank">IMAX 3D</a></span><span class="theaterMark"><a href="http://web.vscinemas.com.tw/brand/index.aspx?A=3" target="_blank">GC 數位</a></span><span class="more"><a href="detail.aspx?id=5714">more</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5714">侏羅紀世界：統霸天下</a></h2>
#             <h3>JURASSIC WORLD: DOMINION</h3>
#             <time>2022-06-08</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type38">
#             <mark>票房冠軍</mark></span><span class="childview">
#             <mark></mark></span><a href="detail.aspx?id=5713"><img src="../upload/film/film_20220419003.jpg" alt="捍衛戰士：獨行俠" title="捍衛戰士：獨行俠"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span><span class="theaterMark"><a href="http://web.vscinemas.com.tw/brand/index.aspx?A=3" target="_blank">GC 數位</a></span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=1" target="_blank">4DX</a></span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=6" target="_blank">MAPPA</a></span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=13" target="_blank">MUCROWN</a></span><span class="more"><a href="detail.aspx?id=5713">more</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5713">捍衛戰士：獨行俠</a></h2>
#             <h3>TOP GUN: MAVERICK</h3>
#             <time>2022-05-25</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type45">
#             <mark>票房前五</mark></span><span class="bigchild">
#             <mark></mark></span><a href="detail.aspx?id=5733"><img src="../upload/film/film_20220419002.jpg" alt="奇異博士2：失控多重宇宙" title="奇異博士2：失控多重宇宙"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=6" target="_blank">MAPPA</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5733">奇異博士2：失控多重宇宙</a></h2>
#             <h3>DOCTOR STRANGE IN THE MULTIVERSE OF MADNESS</h3>
#             <time>2022-05-04</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type45">
#             <mark>票房前五</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5867"><img src="../upload/film/film_20220510029.jpg" alt="餘命10年" title="餘命10年"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5867">餘命10年</a></h2>
#             <h3>THE LAST 10 YEARS</h3>
#             <time>2022-06-10</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type45">
#             <mark>票房前五</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5886"><img src="../upload/film/film_20220516010.jpg" alt="劇場版FREE! 男子游泳部–the Final Stroke–後篇" title="劇場版FREE! 男子游泳部–the Final Stroke–後篇"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5886">劇場版FREE! 男子游泳部–the Final Stroke–後篇</a></h2>
#             <h3>FREE! -THE FINAL STROKE- THE SECOND VOLUME</h3>
#             <time>2022-06-02</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type31">
#             <mark>特別場</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5715"><img src="../upload/film/film_20220519001.jpg" alt="巴斯光年" title="巴斯光年"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span><span class="theaterMark">3D 數位</span><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/brand/index.aspx?A=2" target="_blank">IMAX</a></span><span class="theaterMark"><a href="http://web.vscinemas.com.tw/brand/index.aspx?A=3" target="_blank">GC 數位</a></span><span class="theaterMark">A+</span><span class="more"><a href="detail.aspx?id=5715">more</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5715">巴斯光年</a></h2>
#             <h3>LIGHTYEAR</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5935"><img src="../upload/film/film_20220607001.jpg" alt="音樂劇《刀劍亂舞》～真劍亂舞祭 2022～現場直播" title="音樂劇《刀劍亂舞》～真劍亂舞祭 2022～現場直播"></a></figure>
#           <section class="iconArea"><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/concert/index.aspx" target="_blank">LIVE</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5935">音樂劇《刀劍亂舞》～真劍亂舞祭 2022～現場直播</a></h2>
#             <h3>TOUKEN RANBU THE MUSICAL SHINKENRANBUSAI2022</h3>
#             <time>2022-06-26</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5897"><img src="../upload/film/film_20220513002.jpg" alt="D3-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播" title="D3-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播"></a></figure>
#           <section class="iconArea"><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/concert/index.aspx" target="_blank">LIVE</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5897">D3-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播</a></h2>
#             <h3>D3-ENSEMBLE STARS!! DREAM LIVE 6TH TOUR -SYNCHRONIC SPHERES- LIVE VIEWING</h3>
#             <time>2022-06-26</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5898"><img src="../upload/film/film_20220513003.jpg" alt="D2-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播" title="D2-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播"></a></figure>
#           <section class="iconArea"><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/concert/index.aspx" target="_blank">LIVE</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5898">D2-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播</a></h2>
#             <h3>D2-ENSEMBLE STARS!! DREAM LIVE 6TH TOUR -SYNCHRONIC SPHERES- LIVE VIEWING</h3>
#             <time>2022-06-25</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5899"><img src="../upload/film/film_20220513004.jpg" alt="D1-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播" title="D1-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播"></a></figure>
#           <section class="iconArea"><span class="theaterMark"><a href="https://www.vscinemas.com.tw/vsweb/concert/index.aspx" target="_blank">LIVE</a></span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5899">D1-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播</a></h2>
#             <h3>D1-ENSEMBLE STARS!! DREAM LIVE 6TH TOUR -SYNCHRONIC SPHERES- LIVE VIEWING</h3>
#             <time>2022-06-24</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="childview">
#             <mark></mark></span><a href="detail.aspx?id=5906"><img src="../upload/film/film_20220516021.jpg" alt="羅密歐與茱麗葉 (英國國家劇院現場)" title="羅密歐與茱麗葉 (英國國家劇院現場)"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5906">羅密歐與茱麗葉 (英國國家劇院現場)</a></h2>
#             <h3>Romeo & Juliet (National Theatre Live)</h3>
#             <time>2022-06-10</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5905"><img src="../upload/film/film_20220516017.jpg" alt="利奥波德城(英國國家劇院現場)" title="利奥波德城(英國國家劇院現場)"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5905">利奥波德城(英國國家劇院現場)</a></h2>
#             <h3>Leopoldstadt (National Theatre Live)</h3>
#             <time>2022-06-10</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type12">
#             <mark>獨家</mark></span><span class="general">
#             <mark></mark></span><a href="detail.aspx?id=5904"><img src="../upload/film/film_20220516012.jpg" alt="伊恩·麥克連 80歲個人秀巡迴演出(英國國家劇院現場)" title="伊恩·麥克連 80歲個人秀巡迴演出(英國國家劇院現場)"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5904">伊恩·麥克連 80歲個人秀巡迴演出(英國國家劇院現場)</a></h2>
#             <h3>Ian McKellen on Stage (National Theatre Live)</h3>
#             <time>2022-06-10</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="teenager">
#             <mark></mark></span><a href="detail.aspx?id=5924"><img src="../upload/film/film_20220606014.jpg" alt="一屍到底：法屍浪漫" title="一屍到底：法屍浪漫"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5924">一屍到底：法屍浪漫</a></h2>
#             <h3>FINAL CUT</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="bigchild">
#             <mark></mark></span><a href="detail.aspx?id=5913"><img src="../upload/film/film_20220606007.jpg" alt="台灣男子葉石濤" title="台灣男子葉石濤"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5913">台灣男子葉石濤</a></h2>
#             <h3>YEH SHIH - TAO , A TAIWAN MAN</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="childview">
#             <mark></mark></span><a href="detail.aspx?id=5927"><img src="../upload/film/film_20220607014.jpg" alt="來自巴黎的情書" title="來自巴黎的情書"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5927">來自巴黎的情書</a></h2>
#             <h3>THE LOVE LETTER</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="teenager">
#             <mark></mark></span><a href="detail.aspx?id=5917"><img src="../upload/film/film_20220606016.jpg" alt="隔離巢" title="隔離巢"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5917">隔離巢</a></h2>
#             <h3>NEST</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="teenager">
#             <mark></mark></span><a href="detail.aspx?id=5925"><img src="../upload/film/film_20220527007.jpg" alt="蘿莉塔" title="蘿莉塔"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5925">蘿莉塔</a></h2>
#             <h3>LOLITA</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="bigchild">
#             <mark></mark></span><a href="detail.aspx?id=5916"><img src="../upload/film/film_20220527013.jpg" alt="午後彌撒" title="午後彌撒"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5916">午後彌撒</a></h2>
#             <h3>MASS</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#         <li>
#           <figure><span class="type type">
#             <mark></mark></span><span class="teenager">
#             <mark></mark></span><a href="detail.aspx?id=5903"><img src="../upload/film/film_20220601001.jpg" alt="尋人啟弒" title="尋人啟弒"></a></figure>
#           <section class="iconArea"><span class="theaterMark">數位</span></section>
#           <section class="infoArea">
#             <h2><a href="detail.aspx?id=5903">尋人啟弒</a></h2>
#             <h3>MISSING</h3>
#             <time>2022-06-17</time>
#           </section>
#         </li>
#
#       </ul>
#       <!--頁碼-->
#       <section class="pagebar">
#         <ul><li><a href="?p=1" class="icon-arrow-left"></a></li> <li class="press"><a>1</a></li> <li><a href="?p=2">2</a></li><li><a href="?p=2" class="icon-arrow-right"></a></li></ul>
#       </section>
#
#     </article>
#
#
# <footer class="footer">
#   <div class="footerArea">
#     <ul class="footerLink"><a href="#" class="popupClose"></a>
#       <li><a href="../theater/index.aspx">影城介紹</a></li>
#       <li><a href="#" class="footerFirst">電影介紹</a>
#
#         <ul>
#
#           <li><a href="../film/index.aspx">熱售中</a></li>
#           <li><a href="../film/coming.aspx">即將上映</a></li>
#         </ul>
#       </li>
#       <li><a href="../brand/index.aspx" class="footerFirst">映演品牌</a>
#         <ul>
#
#
#           <li><a href="../brand/index.aspx?A=12">TITAN SCREEN</a></li>
#
#           <li><a href="../brand/index.aspx?A=13">MUCROWN</a></li>
#
#           <li><a href="../brand/index.aspx?A=2">IMAX</a></li>
#
#           <li><a href="../brand/index.aspx?A=1">4DX</a></li>
#
#           <li><a href="../brand/index.aspx?A=3">GOLD CLASS</a></li>
#
#           <li><a href="../brand/index.aspx?A=6">Mappa</a></li>
#
#           <li><a href="../concert/index.aspx">LIVE演唱會</a></li>
#         </ul>
#       </li>
#       <li><a href="../food/index.aspx" class="footerFirst">餐飲與商品</a>
#         <ul>
#           <li><a href="../food/index.aspx">影城餐飲</a></li>
#           <!--<li><a href="themed/index.aspx">主題商品</a></li>-->
#           <li><a href="https://www.unicornpopcorn.com.tw/" target="_blank">UNICORN</a></li>
#
#         </ul>
#       </li>
#       <li><a href="../event/index.aspx" class="footerFirst">活動公告</a>
#         <ul>
#           <li><a href="../event/news.aspx">影城公告</a></li>
#           <li><a href="../event/index.aspx">影城活動</a></li>
#           <li><a href="../event/prize.aspx">中獎名單</a></li>
#           <li><a href="../event/partner.aspx">合作夥伴</a></li>
#         </ul>
#       </li>
#       <li><a href="../biz/index.aspx">業務專區</a></li>
#       <li><a href="../mall/index.aspx" class="footerFirst">威秀商場</a>
#         <ul>
#           <li><a href="../mall/index.aspx">商家介紹</a></li>
#           <li><a href="../mall/event_list.aspx">商場活動</a></li>
#         </ul>
#       </li>
#       <li><a href="../ishow/index.aspx" class="footerFirst">iShow專區</a>
#         <ul>
#           <!--<li><a href="ishow/card.aspx">加入iShow</a></li>-->
# 					<li><a href="https://www.vscinemas.com.tw/vsweb/ishow/card.aspx">加入iShow</a></li>
#           <!--<li><a href="ishow/exchangeList.aspx">兌點商品</a></li>-->
#           <li><a href="../event/index.aspx?E=1">會員活動</a></li>
#           <li><a href="../qa/qalist.aspx">會員Q&A</a></li>
#         </ul>
#       </li>
#     </ul>
#     <!--版權列-->
#     <address class="copyright">
#       <script type="text/javascript" charset="utf-8" >
#         <!--
#           var twca_cn="www.vscinemas.com.tw";
#         -->
#       </script>
#       <section class="twcaArea">
#
# 				<!--<div id="twcaseal" class="small1 twcaseal"><a href="#"><img src="https://www.vscinemas.com.tw/vsweb/images/twcaseal.jpg" alt="" border="0" class="twcasealpic"></a></div>-->
#         <div class="small1 twcaseal">
#             <a href="https://ssl2.twca.com.tw/NCWebSSL/certinfo.htm?DNS=www.vscinemas.com.tw&SerialNumber=95564223681339173939985681985773720830" target="_blank">
#           <img src="https://www.vscinemas.com.tw/vsweb/images/twcaseal.jpg" alt="" border="0" class="twcasealpic"></a></div>
#         <script type="text/javascript" charset="utf-8" src="//ssllogo.twca.com.tw/twcaseal_v3.js"></script>
#         <!--
# 					<script type="text/javascript" charset="utf-8" src="//ssllogo.twca.com.tw/twcaseal2_v3.js"></script>
# 					<div class="twca"><a href="https://ssl2.twca.com.tw/NCWebSSL/certinfo.htm?DNS=www.vscinemas.com.tw&amp;SerialNumber=95538262197041383913239949513363445874" target="_blank">
#           <img src="https://www.vscinemas.com.tw/images/MINI.GIF" border="0" alt=""></a></div>
# 				-->
#       </section>
#       <p>Copyright &copy 2016 威秀影城 VIESHOW Cinemas. All Rights Reserved.</p>
#       <ul class="addressLink">
#
#         <li><a href="../about/index.aspx?A=1">關於威秀</a></li>
#
#         <li><a href="../about/recruit.aspx">人才招募</a></li>
#         <li><a href="https://www.vscinemas.com.tw/vsweb/qa/InvoiceInfo.aspx">電子發票</a></li>
#         <li><a href="../about/privacy.aspx">隱私權政策</a></li>
#         <li class="open">網站地圖<span class="footerOpen"></span></li>
#       </ul>
#     </address>
#   </div>
# </footer>
#
#
#
#     <div id="browserBar" class="browserBar">
#       <p>您的瀏覽器版本已過時許久，請更新您的瀏覽器以便獲得更好的體驗!</p><a href="http://windows.microsoft.com/zh-tw/internet-explorer/download-ie" target="_blank"><img src="../images/IE.png" alt="下載最新版IE瀏覽器" title="下載最新版IE瀏覽器" class="explore"></a><a href="https://www.google.com/intl/zh-TW/chrome/" target="_blank"><img src="../images/Chrome.png" alt="下載最新版Chrome瀏覽器" title="下載最新版Chrome瀏覽器" class="explore"></a><a href="http://moztw.org/firefox/" target="_b lank"><img src="../images/Firefox.png" alt="下載最新版Firefox瀏覽器" title="下載最新版Firefox瀏覽器" class="explore"></a><a href="http://www.apple.com/tw/safari/" target="_blank"><img src="../images/Safari.png" alt="下載最新版Safari瀏覽器" title="下載最新版Safari瀏覽器" class="explore"></a><a href="http://www.opera.com/zh-tw" target="_blank"><img src="../images/Opera.png" alt="下載最新版Opera瀏覽器" title="下載最新版Opera瀏覽器" class="explore"></a>
#     </div>
#     <div id="browser" class="browserWindow">
#       <section class="browserArea">
#         <h1>很抱歉!</h1><a href="#" onclick="closePopup()" id="close" class="icon-delete"></a>
#         <section class="group">
#           <p>您的瀏覽器版本已過時許久，威秀影城無法支援您的版本，請更新您的瀏覽器以便獲得更好的動畫瀏覽體驗!</p>
#           <p>若您開啟相容性，請關閉相容性即可瀏覽!</p>
#           <section class="helf">
#             <p class="note">如果您是Windows XP使用者，建議您安裝:</p><a href="https://www.google.com/intl/zh-TW/chrome/" target="_blank"><img src="../images/Chrome.png" alt="下載最新版Chrome瀏覽器" title="下載最新版Chrome瀏覽器" class="explore"></a><a href="http://moztw.org/firefox/" target="_b lank"><img src="../images/Firefox.png" alt="下載最新版Firefox瀏覽器" title="下載最新版Firefox瀏覽器" class="explore"></a><a href="http://www.apple.com/tw/safari/" target="_blank"><img src="../images/Safari.png" alt="下載最新版Safari瀏覽器" title="下載最新版Safari瀏覽器" class="explore"></a><a href="http://www.opera.com/zh-tw" target="_blank"><img src="../images/Opera.png" alt="下載最新版Opera瀏覽器" title="下載最新版Opera瀏覽器" class="explore"></a>
#           </section>
#           <section class="helf">
#             <p class="note">如果您是Windows Vista / 7使用者，建議您安裝:</p><a href="http://windows.microsoft.com/zh-tw/internet-explorer/download-ie" target="_blank"><img src="../images/IE.png" alt="下載最新版IE瀏覽器" title="下載最新版IE瀏覽器" class="explore"></a><a href="https://www.google.com/intl/zh-TW/chrome/" target="_blank"><img src="../images/Chrome.png" alt="下載最新版Chrome瀏覽器" title="下載最新版Chrome瀏覽器" class="explore"></a><a href="http://moztw.org/firefox/" target="_b lank"><img src="../images/Firefox.png" alt="下載最新版Firefox瀏覽器" title="下載最新版Firefox瀏覽器" class="explore"></a><a href="http://www.apple.com/tw/safari/" target="_blank"><img src="../images/Safari.png" alt="下載最新版Safari瀏覽器" title="下載最新版Safari瀏覽器" class="explore"></a><a href="http://www.opera.com/zh-tw" target="_blank"><img src="../images/Opera.png" alt="下載最新版Opera瀏覽器" title="下載最新版Opera瀏覽器" class="explore"></a>
#           </section>
#         </section>
#       </section>
#     </div>
#
#     <!--[if lte IE 8]>
#     <script type="text/javascript">
#         document.getElementById('browserBar').style.visibility='visible';
#         document.getElementById('browser').style.visibility='visible';
#         document.getElementById('close').onclick=closePopup;
#         function closePopup(){
#         document.getElementById('browser').style.visibility='hidden';
#         }
#     </script><![endif]-->
#
#   </body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')
movies=soup.find('ul',class_='movieList')

# %%
for liTag in movies.find_all('li'):
    print(liTag.find('section',class_='infoArea').h2.a.string)
# Out:
# 侏羅紀世界：統霸天下
# 捍衛戰士：獨行俠
# 奇異博士2：失控多重宇宙
# 餘命10年
# 劇場版FREE! 男子游泳部–the Final Stroke–後篇
# 巴斯光年
# 音樂劇《刀劍亂舞》～真劍亂舞祭 2022～現場直播
# D3-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播
# D2-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播
# D1-偶像夢幻祭!! DREAM LIVE 6th Tour -Synchronic Spheres- 現場直播
# 羅密歐與茱麗葉 (英國國家劇院現場)
# 利奥波德城(英國國家劇院現場)
# 伊恩·麥克連 80歲個人秀巡迴演出(英國國家劇院現場)
# 一屍到底：法屍浪漫
# 台灣男子葉石濤
# 來自巴黎的情書
# 隔離巢
# 蘿莉塔
# 午後彌撒
# 尋人啟弒
